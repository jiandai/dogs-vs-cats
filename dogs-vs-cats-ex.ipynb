# %% [markdown]
# ### Transfer Learning Example
#
# #### Goal
# - Take dogs-vs-cats Kaggle dataset
# - Use pretrained Xception to predict ImageNet label
# - Use an online lookup to translate Imagenet label to dogs-vs-cats classification

# %% [markdown]
# #### Summary of result
# Predict Imagenet labels of 25000 cases in dogs-vd-cats training dataset directly using Xception without training
# - 23156 correct prediction
# - 1190 cases are classified not as dog and cat categories (1056 from dog, 134 from cat)
# - 17 dogs misclassified as cat
# - 637 cats misclassified as dog
# - Accuracy and error rate as follows

# %%
# Accuracy vs error rate
23156/25000, (1190 + 654) / 25000
# Out:
# (0.92624, 0.07376)

# %% [markdown]
# #### Ref
# - ImageNet labels to dog-vs-cat map
# https://github.com/zygmuntz/kaggle-cats-and-dogs/
# Specifically,
# https://github.com/zygmuntz/kaggle-cats-and-dogs/blob/master/overfeat/compute_train_acc.py
# https://github.com/zygmuntz/kaggle-cats-and-dogs/blob/master/overfeat/predict.py

# %%
cf = open('kaggle-cats-and-dogs\overfeat\data\cats.txt')
cats = cf.read()
cats = cats.split( "\n" )

# %%
df = open('kaggle-cats-and-dogs\overfeat\data\dogs.txt')
dogs = df.read()
dogs = dogs.split( "\n" )

# %%
dog_labels = [x.split(',')[0] for x in dogs]
cat_labels = [x.split(',')[0] for x in cats]

# %%
# The prediction is run on the GPU cluster by using Keras Xception pretrained model
import pandas as pd
raw = pd.read_csv('raw_prediction.csv')

# %%
pred = []

# %%
for r in range(raw.shape[0]):
    cls = raw['class'][r].replace('_',' ') # Remove the underscore from the direct ImageNet label prediction
    if cls in dog_labels:
        pred.append('dog')
    elif cls in cat_labels:
        pred.append('cat')
    else:
        pred.append('unknown')

# %%
raw['pred'] = pred

# %%
# Summary
raw.groupby(['truth','pred']).size()
# Out:
# truth  pred
# cat    cat        10807
#        dog          637
#        unknown     1056
# dog    cat           17
#        dog        12349
#        unknown      134
# dtype: int64

# %%
# Totaly ERROR rate
(1190 + 654) / 25000
# Out:
# 0.07376

# %%
raw[(raw.pred != 'unknown') & (raw.pred != raw.truth)]
# Out:
#        Unnamed: 0         id                    class      prob truth  \
# 49             49  n02104365               schipperke  0.129365   cat
# 61             61  n02105412                   kelpie  0.156135   cat
# 79             79  n02120505                 grey_fox  0.175790   cat
# 85             85  n02086910                 papillon  0.077606   cat
# 99             99  n02120505                 grey_fox  0.268015   cat
# 120           120  n02095314  wire-haired_fox_terrier  0.502985   cat
# 122           122  n02106382     Bouvier_des_Flandres  0.229874   cat
# 129           129  n02120505                 grey_fox  0.087596   cat
# 157           157  n02113186                 Cardigan  0.574266   cat
# 185           185  n02113186                 Cardigan  0.108588   cat
# 301           301  n02104365               schipperke  0.089755   cat
# 319           319  n02110185           Siberian_husky  0.078326   cat
# 415           415  n02085782         Japanese_spaniel  0.077731   cat
# 418           418  n02105855        Shetland_sheepdog  0.137786   cat
# 435           435  n02110185           Siberian_husky  0.523378   cat
# 528           528  n02104365               schipperke  0.062830   cat
# 601           601  n02097298           Scotch_terrier  0.322715   cat
# 694           694  n02104365               schipperke  0.341706   cat
# 717           717  n02110185           Siberian_husky  0.176543   cat
# 755           755  n02104365               schipperke  0.307988   cat
# 793           793  n02111500           Great_Pyrenees  0.230565   cat
# 801           801  n02443484      black-footed_ferret  0.131624   dog
# 812           812  n02106166            Border_collie  0.107679   cat
# 880           880  n02087046              toy_terrier  0.048877   cat
# 935           935  n02104365               schipperke  0.133395   cat
# 958           958  n02105855        Shetland_sheepdog  0.090726   cat
# 979           979  n02104365               schipperke  0.378419   cat
# 1018         1018  n02097298           Scotch_terrier  0.068689   cat
# 1061         1061  n02120079               Arctic_fox  0.095286   cat
# 1199         1199  n02097298           Scotch_terrier  0.191583   cat
# ...           ...        ...                      ...       ...   ...
# 24176       24176  n02111500           Great_Pyrenees  0.263079   cat
# 24207       24207  n02105056              groenendael  0.243436   cat
# 24243       24243  n02106030                   collie  0.548065   cat
# 24251       24251  n02105056              groenendael  0.128773   cat
# 24252       24252  n02097298           Scotch_terrier  0.226463   cat
# 24270       24270  n02104365               schipperke  0.110906   cat
# 24312       24312  n02105056              groenendael  0.129890   cat
# 24339       24339  n02110185           Siberian_husky  0.160321   cat
# 24346       24346  n02104365               schipperke  0.321256   cat
# 24433       24433  n02105412                   kelpie  0.240872   cat
# 24488       24488  n02110185           Siberian_husky  0.131776   cat
# 24496       24496  n02106166            Border_collie  0.222468   cat
# 24526       24526  n02088632                 bluetick  0.249915   cat
# 24560       24560  n02104365               schipperke  0.219017   cat
# 24579       24579  n02105412                   kelpie  0.331063   cat
# 24618       24618  n02110185           Siberian_husky  0.343740   cat
# 24640       24640  n02094258          Norwich_terrier  0.076415   cat
# 24643       24643  n02105056              groenendael  0.466269   cat
# 24663       24663  n02096177                    cairn  0.177326   cat
# 24664       24664  n02085620                Chihuahua  0.083001   cat
# 24666       24666  n02104365               schipperke  0.205596   cat
# 24689       24689  n02102040         English_springer  0.164918   cat
# 24721       24721  n02110185           Siberian_husky  0.085452   cat
# 24749       24749  n02092002       Scottish_deerhound  0.286556   cat
# 24759       24759  n02087046              toy_terrier  0.258757   cat
# 24782       24782  n02110185           Siberian_husky  0.079781   cat
# 24911       24911  n02104365               schipperke  0.149624   cat
# 24919       24919  n02123597              Siamese_cat  0.126709   dog
# 24948       24948  n02113186                 Cardigan  0.129721   cat
# 24962       24962  n02104365               schipperke  0.415805   cat
#
#                 file pred
# 49     cat.11665.jpg  dog
# 61     cat.10107.jpg  dog
# 79     cat.11871.jpg  dog
# 85     cat.12098.jpg  dog
# 99      cat.5539.jpg  dog
# 120      cat.599.jpg  dog
# 122    cat.10609.jpg  dog
# 129     cat.3931.jpg  dog
# 157     cat.6748.jpg  dog
# 185     cat.6703.jpg  dog
# 301    cat.11722.jpg  dog
# 319     cat.1192.jpg  dog
# 415    cat.12126.jpg  dog
# 418     cat.2801.jpg  dog
# 435     cat.3148.jpg  dog
# 528     cat.1685.jpg  dog
# 601    cat.12392.jpg  dog
# 694     cat.1188.jpg  dog
# 717     cat.2903.jpg  dog
# 755     cat.8887.jpg  dog
# 793     cat.6051.jpg  dog
# 801     dog.2500.jpg  cat
# 812     cat.5839.jpg  dog
# 880      cat.709.jpg  dog
# 935      cat.297.jpg  dog
# 958     cat.1185.jpg  dog
# 979     cat.2150.jpg  dog
# 1018    cat.5830.jpg  dog
# 1061   cat.11856.jpg  dog
# 1199    cat.2832.jpg  dog
# ...              ...  ...
# 24176  cat.12378.jpg  dog
# 24207   cat.4142.jpg  dog
# 24243   cat.9250.jpg  dog
# 24251  cat.12393.jpg  dog
# 24252  cat.11977.jpg  dog
# 24270    cat.245.jpg  dog
# 24312  cat.10614.jpg  dog
# 24339  cat.11449.jpg  dog
# 24346  cat.12146.jpg  dog
# 24433   cat.7550.jpg  dog
# 24488   cat.5673.jpg  dog
# 24496  cat.10603.jpg  dog
# 24526   cat.8138.jpg  dog
# 24560   cat.6876.jpg  dog
# 24579   cat.4629.jpg  dog
# 24618   cat.1672.jpg  dog
# 24640  cat.12240.jpg  dog
# 24643   cat.1263.jpg  dog
# 24663   cat.6017.jpg  dog
# 24664   cat.6430.jpg  dog
# 24666  cat.11438.jpg  dog
# 24689   cat.7936.jpg  dog
# 24721   cat.5297.jpg  dog
# 24749   cat.4773.jpg  dog
# 24759   cat.7600.jpg  dog
# 24782  cat.10301.jpg  dog
# 24911    cat.177.jpg  dog
# 24919   dog.2647.jpg  cat
# 24948   cat.2999.jpg  dog
# 24962    cat.506.jpg  dog
#
# [654 rows x 7 columns]

# %%
raw[raw.pred == 'unknown']
# Out:
#        Unnamed: 0         id                   class      prob truth  \
# 15             15  n02133161     American_black_bear  0.258392   dog
# 34             34  n04599235                    wool  0.109830   cat
# 42             42  n03223299                 doormat  0.292160   cat
# 44             44  n02492660           howler_monkey  0.298832   cat
# 67             67  n03803284                  muzzle  0.929156   dog
# 78             78  n04493381                     tub  0.174189   cat
# 88             88  n02909870                  bucket  0.230651   cat
# 118           118  n01675722            banded_gecko  0.328046   cat
# 132           132  n01883070                  wombat  0.571488   dog
# 141           141  n02797295                  barrow  0.382083   cat
# 151           151  n03223299                 doormat  0.970265   cat
# 196           196  n02971356                  carton  0.955063   cat
# 253           253  n04265275            space_heater  0.051712   cat
# 261           261  n04005630                  prison  0.129207   dog
# 263           263  n03223299                 doormat  0.101800   cat
# 272           272  n03958227             plastic_bag  0.612201   cat
# 293           293  n01883070                  wombat  0.356283   cat
# 325           325  n02808304              bath_towel  0.212328   cat
# 341           341  n04493381                     tub  0.294717   cat
# 342           342  n01855032  red-breasted_merganser  0.043669   cat
# 343           343  n02909870                  bucket  0.698551   cat
# 383           383  n02808304              bath_towel  0.234306   cat
# 392           392  n04238763              slide_rule  0.083296   cat
# 409           409  n03207941              dishwasher  0.081755   cat
# 423           423  n02804414                bassinet  0.441535   cat
# 424           424  n02971356                  carton  0.371872   cat
# 433           433  n02133161     American_black_bear  0.146825   dog
# 449           449  n02493509                    titi  0.174350   cat
# 462           462  n01883070                  wombat  0.394735   cat
# 463           463  n04553703               washbasin  0.716004   cat
# ...           ...        ...                     ...       ...   ...
# 24263       24263  n03930313            picket_fence  0.244475   cat
# 24272       24272  n02808304              bath_towel  0.761813   cat
# 24285       24285  n04081281              restaurant  0.382040   cat
# 24384       24384  n04235860            sleeping_bag  0.166225   cat
# 24391       24391  n03141823                  crutch  0.097959   cat
# 24398       24398  n06359193                web_site  0.628682   cat
# 24401       24401  n04033995                   quilt  0.182212   cat
# 24416       24416  n02797295                  barrow  0.891779   cat
# 24522       24522  n03325584             feather_boa  0.450299   cat
# 24532       24532  n04033995                   quilt  0.039432   cat
# 24561       24561  n02808304              bath_towel  0.255086   cat
# 24570       24570  n04344873            studio_couch  0.289448   cat
# 24624       24624  n04099969           rocking_chair  0.126598   cat
# 24658       24658  n04553703               washbasin  0.124763   cat
# 24687       24687  n03131574                    crib  0.364567   cat
# 24784       24784  n04589890           window_screen  0.366266   cat
# 24792       24792  n03887697             paper_towel  0.672627   cat
# 24804       24804  n03223299                 doormat  0.128514   cat
# 24817       24817  n03924679             photocopier  0.131940   cat
# 24818       24818  n03207941              dishwasher  0.239047   cat
# 24840       24840  n03000134         chainlink_fence  0.439157   dog
# 24878       24878  n02808304              bath_towel  0.523736   cat
# 24904       24904  n04033995                   quilt  0.117991   cat
# 24916       24916  n06785654        crossword_puzzle  0.665961   cat
# 24935       24935  n03887697             paper_towel  0.286200   cat
# 24936       24936  n04033995                   quilt  0.335378   cat
# 24941       24941  n01817953            African_grey  0.107198   cat
# 24966       24966  n03642806                  laptop  0.084801   cat
# 24974       24974  n01883070                  wombat  0.245232   dog
# 24982       24982  n02834397                     bib  0.410068   cat
#
#                 file     pred
# 15     dog.10844.jpg  unknown
# 34      cat.5418.jpg  unknown
# 42      cat.5844.jpg  unknown
# 44      cat.8455.jpg  unknown
# 67      dog.6159.jpg  unknown
# 78      cat.7460.jpg  unknown
# 88     cat.10096.jpg  unknown
# 118     cat.1865.jpg  unknown
# 132     dog.8457.jpg  unknown
# 141      cat.329.jpg  unknown
# 151     cat.2749.jpg  unknown
# 196     cat.4786.jpg  unknown
# 253    cat.11109.jpg  unknown
# 261      dog.729.jpg  unknown
# 263      cat.114.jpg  unknown
# 272     cat.8199.jpg  unknown
# 293    cat.11607.jpg  unknown
# 325     cat.5334.jpg  unknown
# 341     cat.3102.jpg  unknown
# 342     cat.5527.jpg  unknown
# 343    cat.11339.jpg  unknown
# 383     cat.4789.jpg  unknown
# 392     cat.7968.jpg  unknown
# 409     cat.6633.jpg  unknown
# 423     cat.8442.jpg  unknown
# 424     cat.5123.jpg  unknown
# 433     dog.9518.jpg  unknown
# 449     cat.1386.jpg  unknown
# 462     cat.2869.jpg  unknown
# 463     cat.4520.jpg  unknown
# ...              ...      ...
# 24263   cat.3998.jpg  unknown
# 24272  cat.11305.jpg  unknown
# 24285   cat.3672.jpg  unknown
# 24384   cat.9902.jpg  unknown
# 24391   cat.2974.jpg  unknown
# 24398  cat.10712.jpg  unknown
# 24401  cat.11815.jpg  unknown
# 24416   cat.6235.jpg  unknown
# 24522   cat.4123.jpg  unknown
# 24532   cat.9947.jpg  unknown
# 24561   cat.3273.jpg  unknown
# 24570   cat.4226.jpg  unknown
# 24624   cat.7603.jpg  unknown
# 24658   cat.2528.jpg  unknown
# 24687   cat.3868.jpg  unknown
# 24784   cat.8919.jpg  unknown
# 24792   cat.9163.jpg  unknown
# 24804   cat.9701.jpg  unknown
# 24817   cat.3343.jpg  unknown
# 24818  cat.10299.jpg  unknown
# 24840   dog.8627.jpg  unknown
# 24878   cat.6888.jpg  unknown
# 24904     cat.63.jpg  unknown
# 24916   cat.2444.jpg  unknown
# 24935   cat.4522.jpg  unknown
# 24936  cat.10951.jpg  unknown
# 24941   cat.4190.jpg  unknown
# 24966   cat.7265.jpg  unknown
# 24974  dog.10425.jpg  unknown
# 24982   cat.5633.jpg  unknown
#
# [1190 rows x 7 columns]

# %%
raw.to_csv('processed_prediction.csv')
